# %% [markdown]
# # Strategy generation from signal
#
# **Asset:** SOLUSDT
#
# **Goal:**In the previous notebook we already built a ML model that exploited the OFI, in this section we will use the Avellaneda-Stoikov model for creating a trading strategy.
